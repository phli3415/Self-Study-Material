# %% [markdown]
# 关于对话模型的Message(消息)

# %% [markdown]
# 标准的对话模型的调用过程:
#
# invoke()的输入可以是多种类型，典型的类型有: ⦾ 字符串类型 ⦾ 消息列表
# invoke()的输出类型: BaseMessage的子类: AIMessage

# %%
import os
from langchain_openai import ChatOpenAI
import dotenv

dotenv.load_dotenv()

# 从环境变量读取密钥
# 环境变量放到run-> edit configuration里
llm = ChatOpenAI(
    model="gpt-4o-mini"
)
response = llm.invoke("LangChain 是什么？")

# 3、处理响应数据
# print(response)
print(response.content)
print(type(response)) # <class 'langchain_core.messages.ai.AIMessage'>
# Out:
# content='LangChain 是一个用于构建与语言模型（如 OpenAI 的 GPT-3）交互的应用程序的框架。它提供了一系列工具和库，帮助开发者更高效地创建多种类型的应用，包括对话代理、问答系统、文本生成等。\n\nLangChain 的主要特点包括：\n\n1. **模块化设计**：LangChain 将功能分解成多个模块，开发者可以根据需要组合使用。例如，处理输入、生成输出和与外部数据源的交互等模块都可以独立使用。\n\n2. **集成外部数据源**：LangChain 允许开发者将语言模型与各种外部数据源（如数据库、API、文件等）结合，使得生成的内容更加丰富和上下文相关。\n\n3. **内置的链式结构**：名称中的 "Chain" 指的是可以将多个操作串联起来，通过这种方式，开发者可以构建复杂的工作流，例如将多个模型或步骤链接在一起，以满足特定的应用需求。\n\n4. **适应性强**：LangChain 支持多种语言模型的使用，允许开发者根据项目的需求选择合适的模型。\n\n5. **社区支持**：作为一个开源框架，LangChain 拥有活跃的社区，可以提供帮助和共享资源。\n\n通过这些特性，LangChain 可以帮助开发者更快速地构建出高效的自然语言处理应用。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 309, 'prompt_tokens': 12, 'total_tokens': 321, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CdNUt89dP7jVQxUjQxEyX94DaUMUm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--c5c516e5-2518-4fa6-a042-624042075e25-0' usage_metadata={'input_tokens': 12, 'output_tokens': 309, 'total_tokens': 321, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain_core.messages import SystemMessage, HumanMessage

system_message = SystemMessage(content="你是一个英语教学方向的专家")
human_message = HumanMessage(content="帮我制定一个英语六级学习的计划")

messages = [system_message, human_message]

print(messages)

# %% [markdown]
# 使用大模型调用消息列表

# %%
response = llm.invoke(messages)
print(response)
print(response.content)
# Out:
# content='当然可以！以下是一个为期三个月的英语六级考试学习计划。这个计划旨在帮助你系统地复习，提高听、说、读、写各方面的能力。\n\n### 第一阶段：基础知识复习 (第1-4周)\n\n#### 第1周：词汇与语法\n- **目标**：积累核心词汇，复习语法知识\n- 每天学习20个六级高频词汇，使用APP或卡片记忆。\n- 每天复习2小时语法知识，重点包括动词时态、从句、被动语态等。\n\n#### 第2周：听力练习\n- **目标**：提高听力理解能力\n- 每天听30分钟六级听力材料（如真题、在线听力资源）。\n- 完成听力练习题，记录错误以便总结。\n\n#### 第3周：阅读理解\n- **目标**：提高阅读速度与理解能力\n- 每天阅读一篇六级阅读理解的文章。\n- 学习并总结文章中的生词与短语，做相关题目。\n\n#### 第4周：写作与翻译\n- **目标**：提升写作与翻译技能\n- 每周写一篇作文，主题可选择六级常考题目。\n- 每天练习翻译句子，尝试中译英和英译中。\n\n### 第二阶段：强化训练 (第5-8周)\n\n#### 第5周：综合练习\n- **目标**：整合所学知识\n- 每天做一套完整的六级模拟题（听力、阅读、写作、翻译）。\n- 关注做题时间和准确率，记录错误并分析原因。\n\n#### 第6周：专项训练\n- **目标**：针对性提高薄弱环节\n- 分析前几周的模拟测试结果，找出薄弱点（如听力或阅读）。\n- 针对薄弱环节进行集中复习与练习。\n\n#### 第7周：口语表达\n- **目标**：提高口语表达能力\n- 每天找一个话题练习口语，录音并回放自我评估。\n- 尝试与同伴进行对话练习，参加口语角或在线交流。\n\n#### 第8周：历年真题\n- **目标**：熟悉考试形式与题型\n- 完成2-3套六级真题，严格按照考试时间进行。\n- 分析真题，记录易错点，及时复习相关知识。\n\n### 第三阶段：模拟与冲刺 (第9-12周)\n\n#### 第9周：全真模拟考试\n- **目标**：测试整体复习效果\n- 每周至少进行1-2次全真模拟考试，注重时间把控。\n- 针对模拟考试中的弱项，进行针对性复习。\n\n#### 第10周：错题重温\n- **目标**：强化记忆与理解\n- 逐日复习之前做错的题目，总结错误原因与知识点。\n- 깊이는 없는 대화와 함께 자신의 지식을 테스트합니다.\n\n#### 第11周：检查与调整\n- **目标**：查缺补漏\n- 检查复习笔记，确保重要知识点都已掌握。\n- 根据情况调整复习计划，重点复习薄弱环节。\n\n#### 第12周：心理调整与轻松复习\n- **目标**：保持良好心态迎接考试\n- 保持每天适量的复习，避免临近考试时的过度紧张。\n- 睡眠充足，保持健康饮食，保持良好的状态应对考试。\n\n### 其他建议\n- 找学习伙伴，共同学习和讨论。\n- 保持积极向上的心态，适当进行体育锻炼，以增强记忆力和专注力。\n\n希望这个计划能帮助你有效地备考英语六级，祝你考试顺利！如果你有任何问题或需要进一步的帮助，请随时告诉我。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 882, 'prompt_tokens': 29, 'total_tokens': 911, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CdNsHVIzZQWh1CIb2faiDstqkmcKl', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--caf1bcd9-483c-4b8e-adc6-9849c1e42320-0' usage_metadata={'input_tokens': 29, 'output_tokens': 882, 'total_tokens': 911, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# 当然可以！以下是一个为期三个月的英语六级考试学习计划。这个计划旨在帮助你系统地复习，提高听、说、读、写各方面的能力。
#
# ### 第一阶段：基础知识复习 (第1-4周)
#
# #### 第1周：词汇与语法
# - **目标**：积累核心词汇，复习语法知识
# - 每天学习20个六级高频词汇，使用APP或卡片记忆。
# - 每天复习2小时语法知识，重点包括动词时态、从句、被动语态等。
#
# #### 第2周：听力练习
# - **目标**：提高听力理解能力
# - 每天听30分钟六级听力材料（如真题、在线听力资源）。
# - 完成听力练习题，记录错误以便总结。
#
# #### 第3周：阅读理解
# - **目标**：提高阅读速度与理解能力
# - 每天阅读一篇六级阅读理解的文章。
# - 学习并总结文章中的生词与短语，做相关题目。
#
# #### 第4周：写作与翻译
# - **目标**：提升写作与翻译技能
# - 每周写一篇作文，主题可选择六级常考题目。
# - 每天练习翻译句子，尝试中译英和英译中。
#
# ### 第二阶段：强化训练 (第5-8周)
#
# #### 第5周：综合练习
# - **目标**：整合所学知识
# - 每天做一套完整的六级模拟题（听力、阅读、写作、翻译）。
# - 关注做题时间和准确率，记录错误并分析原因。
#
# #### 第6周：专项训练
# - **目标**：针对性提高薄弱环节
# - 分析前几周的模拟测试结果，找出薄弱点（如听力或阅读）。
# - 针对薄弱环节进行集中复习与练习。
#
# #### 第7周：口语表达
# - **目标**：提高口语表达能力
# - 每天找一个话题练习口语，录音并回放自我评估。
# - 尝试与同伴进行对话练习，参加口语角或在线交流。
#
# #### 第8周：历年真题
# - **目标**：熟悉考试形式与题型
# - 完成2-3套六级真题，严格按照考试时间进行。
# - 分析真题，记录易错点，及时复习相关知识。
#
# ### 第三阶段：模拟与冲刺 (第9-12周)
#
# #### 第9周：全真模拟考试
# - **目标**：测试整体复习效果
# - 每周至少进行1-2次全真模拟考试，注重时间把控。
# - 针对模拟考试中的弱项，进行针对性复习。
#
# #### 第10周：错题重温
# - **目标**：强化记忆与理解
# - 逐日复习之前做错的题目，总结错误原因与知识点。
# - 깊이는 없는 대화와 함께 자신의 지식을 테스트합니다.
#
# #### 第11周：检查与调整
# - **目标**：查缺补漏
# - 检查复习笔记，确保重要知识点都已掌握。
# - 根据情况调整复习计划，重点复习薄弱环节。
#
# #### 第12周：心理调整与轻松复习
# - **目标**：保持良好心态迎接考试
# - 保持每天适量的复习，避免临近考试时的过度紧张。
# - 睡眠充足，保持健康饮食，保持良好的状态应对考试。
#
# ### 其他建议
# - 找学习伙伴，共同学习和讨论。
# - 保持积极向上的心态，适当进行体育锻炼，以增强记忆力和专注力。
#
# 希望这个计划能帮助你有效地备考英语六级，祝你考试顺利！如果你有任何问题或需要进一步的帮助，请随时告诉我。

# %% [markdown]
# 举列2：

# %%
from langchain_core.messages import SystemMessage, HumanMessage

system_message = SystemMessage(
    content="你是一个英语教学方向的专家",
    additional_kwargs={"tool": "invoke_func1"}
)
human_message = HumanMessage(content="帮我制定一个英语六级学习的计划")

messages = [system_message, human_message]

print(messages)
