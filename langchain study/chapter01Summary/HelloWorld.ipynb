# %%
import dotenv
from langchain_openai import ChatOpenAI
import os

# 调试：检查环境变量
dotenv.load_dotenv()
print("API_KEY exists:", bool(os.getenv("OPENAI_API_KEY")))

try:
    llm = ChatOpenAI(model="gpt-4o-mini")
    response = llm.invoke("什么是大模型？")
    print(response)
except Exception as e:
    print(f"错误: {e}")
# Out:
# API_KEY exists: True
# content='“大模型”通常指的是一种大型的深度学习模型，特别是在人工智能和自然语言处理领域中。这些模型通常具有大量的参数和复杂的结构，能够处理和生成复杂的语言、图像或其他类型的数据。以下是一些关于大模型的关键特点：\n\n1. **规模大**：大模型通常包含数亿到数千亿个参数，这使得它们能够学习和捕捉复杂的数据模式。\n\n2. **预训练与微调**：大模型通常先在大量的通用数据上进行预训练，然后可以通过微调在特定任务上进行优化，从而提高在特定应用中的表现。\n\n3. **迁移学习**：大模型可以通过迁移学习的方式，将在一个领域学到的知识应用到另一个领域，节省训练时间和资源。\n\n4. **应用广泛**：大模型在各种应用中得到了广泛的应用，包括文本生成、机器翻译、图像识别、语音识别等。\n\n5. **计算资源需求高**：由于其庞大的规模，大模型通常需要大量的计算资源和存储空间进行训练和推理，这使得它们的使用和开发相对昂贵。\n\n一些著名的大模型包括OpenAI的GPT（如ChatGPT）、Google的BERT和T5、Meta的LLaMA等。这些模型在多个自然语言处理任务上表现出色，并推动了该领域的快速发展。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 316, 'prompt_tokens': 12, 'total_tokens': 328, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CdMw13KNuGoOZeiUrUjxfCxcynu25', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--cb362a77-5fd1-429f-b3b0-4de46270c24a-0' usage_metadata={'input_tokens': 12, 'output_tokens': 316, 'total_tokens': 328, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
