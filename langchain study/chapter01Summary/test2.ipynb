# %%
import dotenv
from langchain_openai import ChatOpenAI
import os

# %%
# dotenv.load_dotenv()  # 加载当前目录下的 .env 文件
# os.environ.get("OPENAI_API_KEY")
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
# os.environ['OPENAI_BASE_URL'] = os.getenv("OPENAI_BASE_URL")

# %%
llm = ChatOpenAI(model="gpt-4o-mini") # 默认使用 gpt-3.5-turbo

# %%
response = llm.invoke("什么是大模型？")
print(response)
# Out:
# content='“大模型”通常指的是大型的机器学习模型，特别是在自然语言处理（NLP）、计算机视觉和其他人工智能领域中，使用的深度学习模型。这些模型通常具有大量的参数和复杂的结构，能够处理和生成高维数据，比如文本、图像和音频。\n\n大模型的特点包括：\n\n1. **参数规模**：大模型通常有数亿到数百亿的参数，这使得它们能够捕捉到更复杂的模式和特征。\n\n2. **预训练和微调**：许多大模型会先在大规模的数据集上进行预训练，然后在特定任务上进行微调（fine-tuning），以提高在特定应用场景中的表现。\n\n3. **多任务能力**：一些大模型具有处理多种任务的能力，例如同一个模型可以用于文本生成、翻译和问答等多个任务。\n\n4. **迁移学习**：由于大模型能够提取丰富的特征，它们在迁移学习中表现良好，允许开发者在较小的数据集上进行有效的训练，依赖于大模型在大规模数据集上的学习成果。\n\n5. **计算需求**：由于参数众多和复杂的计算结构，大模型通常需要较强的计算资源，训练和推理时可能需要使用专门的硬件，如GPU或TPU。\n\n一些著名的大模型包括OpenAI的GPT系列、Google的BERT、Meta的LLaMA等。这些模型在许多应用中表现出色，推动了人工智能技术的发展。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 339, 'prompt_tokens': 12, 'total_tokens': 351, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-Cce8w6wnYwR2t1dMHM7VsuT6g81zp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--bca927ff-5b81-41b3-b579-b5bb65735dfa-0' usage_metadata={'input_tokens': 12, 'output_tokens': 339, 'total_tokens': 351, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
